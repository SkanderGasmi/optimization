# %% [markdown]
# # Recherches linéaires élémentaires

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f = lambda x : 1/2*x**2

# %%
df= lambda x: x

# %% [markdown]
# ## 1. Condition d’Armijo (comment éviter les pas trop grands)

# %% [markdown]
# ### 1.1 Exemple introductif (page 5)

# %%
def dg_A1(F, Gradf, x0, niter):
.
.
.
.
.
.
    return X, E

# %%
x0 = 2
niter = 30
X,  E = dg_A1(f, df, x0, niter)

# %%
t = np.linspace(-2,2,100)
plt.plot(t,f(t),X[0,:], E[:], 'r.-',);

# %% [markdown]
# ### $\longrightarrow$ Retour au cours

# %% [markdown]
# #### Application (page 11)
# On considère la fonction $f(x,y) = x^2 +y^4$: On suppose qu'à l'itération $k$, on a le point $(x^{(k)}; y^{(k)}) = (1,1)$ et la direction $d^{(k)} =-\nabla f(x^{(k)}; y^{(k)})$
# * Calculez le pas d'Armijo qu'on note $\rho_{Armijo}$, avec les données initiales suivantes :
# $$
# \rho^{(0)} = 1; \varepsilon = 0,9
# $$

# %%
F = lambda X : X[0]**2+X[1]**4

# %%
DF= lambda X : np.array([2*x[0],4*x[1]**3])

# %%
def Algorithm_Armijo (f,DF,d,x,rho,eps):
    .
    .
    .
    .
    .
    .
    .
    return rho ,k

# %%
r=1
x=np.array([1,1])
epsilon=0.9
d=-DF(x)
R=Algorithm_Armijo (F,DF,d,x,r,epsilon)

# %%
R
# Out:
# (0.015625, 6)

# %% [markdown]
# ### $\longrightarrow$ Retour au cours et comparez le résultat obtenu à la question 1 avec ce résultat.

# %% [markdown]
# ## 2. Condition de Wolf (comment éviter les pas trop petits)

# %%
def dg_A2(F, Gradf, x0, niter):
    .
    .
    .
    .
    .
    .
    .
    .
    
    return X, E

# %%
x0 = 2
niter = 30
X,  E = dg_A2(f, df, x0, niter)

# %%
t = np.linspace(-2,2,100)
plt.plot(t,f(t),X[0,:], E[:], 'r.-',);

# %% [markdown]
# ### $\longrightarrow$ Retour au cours

# %% [markdown]
# ### Application (page 15)

# %%
def Algorithm_wolfe (f,DF,d,x,rho,rho_min,rho_max,eps1,eps2):
.
.
.
.
;
;
.
;

    return rho ,k

# %%
r=1
r_min=0
r_max=10**99
epsilon1=0.1
epsilon2=0.3
RW=Algorithm_wolfe(F,DF,d,x,r,r_min,r_max,epsilon1,epsilon2)

# %%
RW
# Out:
# (0.5, 1)
